# %% [markdown]
# # Preparing Data

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/michaellabelard/medsos/main/medsos.csv'
df = pd.read_csv(url, sep=';')
df.head()
# Out:
#    No                                               Nama  Rating  \
# 0   1  ROBOT Portable Mini Wired Keyboard RK10 Ultra-...       5
# 1   2  ROBOT Portable Mini Wired Keyboard RK10 Ultra-...       5
# 2   3  ROBOT Portable Mini Wired Keyboard RK10 Ultra-...       5
# 3   4  ROBOT Portable Mini Wired Keyboard RK10 Ultra-...       5
# 4   5  ROBOT Portable Mini Wired Keyboard RK10 Ultra-...       4
#
#                                               Review  \
# 0  harga sangat terjangkau, kualitas super bagus....
# 1  Seller responsif. Pengemasan aman👍🏻👍🏻👍🏻. Pengi...
# 2  keyboard nya bagus, ukuran nya jg sedengan gk ...
# 3  pas banget ga panjang juga dan enak pastinya d...
# 4  kecepetan pengirimannya oke, pengemasannya oke...
#
#                                                 Link
# 0  https://shopee.co.id/ROBOT-Portable-Mini-Wired...
# 1  https://shopee.co.id/ROBOT-Portable-Mini-Wired...
# 2  https://shopee.co.id/ROBOT-Portable-Mini-Wired...
# 3  https://shopee.co.id/ROBOT-Portable-Mini-Wired...
# 4  https://shopee.co.id/ROBOT-Portable-Mini-Wired...

# %%
df.tail(3)
# Out:
#       No                                               Nama  Rating  \
# 197  198  AMEN Titan Elite Keyboard Gaming Mechanical Ke...       1
# 198  199  AMEN Titan Elite Keyboard Gaming Mechanical Ke...       1
# 199  200  AMEN Titan Elite Keyboard Gaming Mechanical Ke...       1
#
#                                                 Review  \
# 197  Buat customer² yang terhormat kalau mau belanj...
# 198  pesanan yang datang tidak sesuai yang datang m...
# 199  Barang rusak, giliran mau direfund gaditerima....
#
#                                                   Link
# 197  https://shopee.co.id/GAMEN-Titan-Elite-Keyboar...
# 198  https://shopee.co.id/GAMEN-Titan-Elite-Keyboar...
# 199  https://shopee.co.id/GAMEN-Titan-Elite-Keyboar...

# %%
df = df.dropna()
df.tail(3)
# Out:
#       No                                               Nama  Rating  \
# 197  198  AMEN Titan Elite Keyboard Gaming Mechanical Ke...       1
# 198  199  AMEN Titan Elite Keyboard Gaming Mechanical Ke...       1
# 199  200  AMEN Titan Elite Keyboard Gaming Mechanical Ke...       1
#
#                                                 Review  \
# 197  Buat customer² yang terhormat kalau mau belanj...
# 198  pesanan yang datang tidak sesuai yang datang m...
# 199  Barang rusak, giliran mau direfund gaditerima....
#
#                                                   Link
# 197  https://shopee.co.id/GAMEN-Titan-Elite-Keyboar...
# 198  https://shopee.co.id/GAMEN-Titan-Elite-Keyboar...
# 199  https://shopee.co.id/GAMEN-Titan-Elite-Keyboar...

# %%
df.shape
# Out:
# (200, 5)

# %%
df.describe()
# Out:
#                No      Rating
# count  200.000000  200.000000
# mean   100.500000    3.000000
# std     57.879185    1.417762
# min      1.000000    1.000000
# 25%     50.750000    2.000000
# 50%    100.500000    3.000000
# 75%    150.250000    4.000000
# max    200.000000    5.000000

# %%
df.columns
# Out:
# Index(['No', 'Nama', 'Rating', 'Review', 'Link'], dtype='object')

# %%
df["Rating"].value_counts()
# Out:
# 5    40
# 4    40
# 3    40
# 2    40
# 1    40
# Name: Rating, dtype: int64

# %%
df["Rating"] = df["Rating"].map({ 1 : 'Negatif', 2 : 'Negatif', 3  : 'Negatif', 4 : 'Positif', 5 : 'Positif'})
df["Rating"].value_counts()

#df["Is_Response"] = df["Is_Response"].map({'happy' : 'Positif','not happy' : 'Negatif'})
#df["Is_Response"].value_counts()
# Out:
# Negatif    120
# Positif     80
# Name: Rating, dtype: int64

# %%
df.head()
# Out:
#    No                                               Nama   Rating  \
# 0   1  ROBOT Portable Mini Wired Keyboard RK10 Ultra-...  Positif
# 1   2  ROBOT Portable Mini Wired Keyboard RK10 Ultra-...  Positif
# 2   3  ROBOT Portable Mini Wired Keyboard RK10 Ultra-...  Positif
# 3   4  ROBOT Portable Mini Wired Keyboard RK10 Ultra-...  Positif
# 4   5  ROBOT Portable Mini Wired Keyboard RK10 Ultra-...  Positif
#
#                                               Review  \
# 0  harga sangat terjangkau, kualitas super bagus....
# 1  Seller responsif. Pengemasan aman👍🏻👍🏻👍🏻. Pengi...
# 2  keyboard nya bagus, ukuran nya jg sedengan gk ...
# 3  pas banget ga panjang juga dan enak pastinya d...
# 4  kecepetan pengirimannya oke, pengemasannya oke...
#
#                                                 Link
# 0  https://shopee.co.id/ROBOT-Portable-Mini-Wired...
# 1  https://shopee.co.id/ROBOT-Portable-Mini-Wired...
# 2  https://shopee.co.id/ROBOT-Portable-Mini-Wired...
# 3  https://shopee.co.id/ROBOT-Portable-Mini-Wired...
# 4  https://shopee.co.id/ROBOT-Portable-Mini-Wired...

# %% [markdown]
# # Text Preprocessing
#
# preprosesing disini adalah melakukan, cleaning data teks dengan menghapus kata kata yang tidakpenting yang tidak termsuk dalam konteks, contohnya adalah seperti berikut.

# %%
import re

from bs4 import BeautifulSoup
from nltk.tokenize import WordPunctTokenizer
import nltk
from nltk.corpus import stopwords


tok = WordPunctTokenizer()
pat1 = r'@[A-Za-z0-9_]+' #menghilangkat username jika twitter
pat2 = r'https?://[^ ]+' #menghilangkan situs website
combined_pat = r'|'.join((pat1, pat2)) #join pat1 dan pat 2
www_pat = r'www.[^ ]+' #menhilangkan situs website

#set_stopword yang di deskripsikan sendiri
stp=pd.read_csv("stopwords_id_satya.txt")['STOPWORDS'].tolist()
print(stp)
stopword_user=set(stp)
print(stopword_user)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-5244380f07ea> in <cell line: 16>()
#      14
#      15 #set_stopword yang di deskripsikan sendiri
# ---> 16 stp=pd.read_csv("stopwords_id_satya.txt")['STOPWORDS'].tolist()
#      17 print(stp)
#      18 stopword_user=set(stp)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     603
#     604     # Create the parser.
# --> 605     parser = TextFileReader(filepath_or_buffer, **kwds)
#     606
#     607     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1440
#    1441         self.handles: IOHandles | None = None
# -> 1442         self._engine = self._make_engine(f, self.engine)
#    1443
#    1444     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1733                 if "b" not in mode:
#    1734                     mode += "b"
# -> 1735             self.handles = get_handle(
#    1736                 f,
#    1737                 mode,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854         if ioargs.encoding and "b" not in ioargs.mode:
#     855             # Encoding
# --> 856             handle = open(
#     857                 handle,
#     858                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'stopwords_id_satya.txt'

# %%
def proses_teks(teks):
    soup = BeautifulSoup(teks, 'lxml')
    souped = soup.get_text()
    try:
        teks = souped.decode("utf-8-sig").replace(u"\ufffd", "?")
    except:
        teks = souped
    teks_bersih= re.sub("[^a-zA-Z0-9]", " ",(re.sub(www_pat, '', re.sub(combined_pat, '', teks)).lower()))
    teks_bersih= ' '.join([word for word in teks_bersih.split() if word not in stopword_user])
    return (" ".join([x for x in tok.tokenize(teks_bersih) if len(x) > 1])).strip()

# %%
#teks=

# %%
#proses_teks(teks)

# %%
# contoh penambahan data di kolom
# x=[]
# for i in df.rating:
#   if i >=3:
#     x.append("positif")
#   else:
#     x.append("negatif")

# %%
x =[]
for text in df.Review:
  x.append(proses_teks(text))

# %%
clean_text = pd.DataFrame({'clean_text':x})

# %%
df = pd.concat([df,clean_text],axis=1)

# %%
df.head()

# %% [markdown]
# training 80% testing 20%

# %% [markdown]
# # Vectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer, HashingVectorizer

# %%
cvec=CountVectorizer()
tvec=TfidfVectorizer()
hvec=HashingVectorizer()

# %% [markdown]
# # Create Train_test
#
# Setelah melakukan langkah di atas, maka selanjutnya adalah memisahkan data latih dan data uji, untuk memisahkananya, disini menggunakan pustaka sklearn ~ train test split

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.clean_text
y = df.Rating

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=225)

# %%
print("Banyaknya data X_train: ",len(X_train))
print("Banyaknya data X_test: ",len(X_test))
print("Banyaknya data y_train: ",len(y_train))
print("Banyaknya data y_test: ",len(y_test))

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(token_pattern=r'\b\w+\b')

X_train = vectorizer.fit_transform(X_train)
X_test = vectorizer.transform(X_test)

# %%
print(X_test)

# %% [markdown]
# # Model Definition

# %%
from sklearn.naive_bayes import BernoulliNB

# %%
Model_NB = BernoulliNB()

# %%
#proses pembelajaran mesin
Model_NB.fit(X_train,y_train)

# %%
#kita uji
hasil = Model_NB.predict(X_test)

# %%
print(hasil)
print(y_test)

# %% [markdown]
# # Cek Akurasi

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.metrics import classification_report

# %%
confusion_matrix(hasil,y_test)

# %%
accuracy_score(hasil,y_test)*100

# %%
print(classification_report(y_test,hasil))
